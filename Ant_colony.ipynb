# %%
import random
import numpy as np

# %%
# Task 1: Changed the maze by adding/removing walls
maze = [
    [0, 0, 0],
    [1, 1, 0],
    [0, 0, 0]
]

start, end = (0, 0), (2, 2)

# %%
n_ants = 5
n_iterations = 20
evaporation_rate = 0.1

pheromones = np.ones((len(maze), len(maze[0])))

moves = [(0,1),(0,-1),(1,0),(-1,0)]

# %%
def valid(x, y):
    return 0 <= x < len(maze) and 0 <= y < len(maze[0]) and maze[x][y] == 0

# Add move limit (ant dies if > 10 steps)
# heuristic (pheromone × (1/distance to goal))
def ant_walk(move_limit=10, use_heuristic=False):
    path = [start]
    visited = set([start])
    current = start
    moves_made = 0

    while current != end:
        moves_made += 1
        if moves_made > move_limit:
            return None

        x, y = current
        neighbors = [(x+dx, y+dy) for dx,dy in moves if valid(x+dx,y+dy)]
        if not neighbors:
            return None

        if use_heuristic:
            probs = [pheromones[nx][ny] * (1.0 / (abs(end[0]-nx) + abs(end[1]-ny) + 1))
                     for nx,ny in neighbors]
        else:
            probs = [pheromones[nx][ny] for nx,ny in neighbors]

        total = sum(probs)
        probs = [p/total for p in probs]
        current = random.choices(neighbors, probs)[0]

        if current in visited:
            return None

        visited.add(current)
        path.append(current)

    return path

# %%
def run_simulation(n_ants, use_heuristic=False, independent=False):
    global pheromones
    pheromones = np.ones((len(maze), len(maze[0])))
    best_path = None

    for it in range(1, n_iterations+1):
        print(f"\n Iteration {it}:")
        all_paths = []

        # Task 6: Independent ants option
        iteration_pheromones = np.zeros_like(pheromones)

        for a in range(1, n_ants+1):
            path = ant_walk(move_limit=10, use_heuristic=use_heuristic)
            if path:
                print(f"Ant {a}: SUCCESS (len {len(path)}) {path}")
                all_paths.append(path)

                if independent:
                    # pheromone added only after all ants finish
                    for (x,y) in path:
                        iteration_pheromones[x][y] += 1.0 / len(path)
                else:
                    for (x,y) in path:
                        pheromones[x][y] += 1.0 / len(path)
            else:
                print(f"Ant {a}: FAILED")

        if independent:
            pheromones += iteration_pheromones

        pheromones *= (1 - evaporation_rate)   # evaporation

        # print pheromone grid
        print("Pheromone grid:")
        print(np.round(pheromones, 2))

        if all_paths:
            best = min(all_paths, key=len)
            if best_path is None or len(best) < len(best_path):
                best_path = best
        print(f"Best so far: {len(best_path) if best_path else None} steps")

    print("\nFinal Best Path:", best_path)

# %%
# Compare with small and large numbers of ants
print(" Simulation with 2 ants:")
run_simulation(n_ants=2)

print("\n\n Simulation with 20 ants:")
run_simulation(n_ants=20)
# Out:
#  Simulation with 2 ants:
#
#  Iteration 1:
# Ant 1: FAILED
# Ant 2: FAILED
# Pheromone grid:
# [[0.9 0.9 0.9]
#  [0.9 0.9 0.9]
#  [0.9 0.9 0.9]]
# Best so far: None steps
#
#  Iteration 2:
# Ant 1: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 2: FAILED
# Pheromone grid:
# [[0.99 0.99 0.99]
#  [0.81 0.81 0.99]
#  [0.81 0.81 0.99]]
# Best so far: 5 steps
#
#  Iteration 3:
# Ant 1: FAILED
# Ant 2: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Pheromone grid:
# [[1.07 1.07 1.07]
#  [0.73 0.73 1.07]
#  [0.73 0.73 1.07]]
# Best so far: 5 steps
#
#  Iteration 4:
# Ant 1: FAILED
# Ant 2: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Pheromone grid:
# [[1.14 1.14 1.14]
#  [0.66 0.66 1.14]
#  [0.66 0.66 1.14]]
# Best so far: 5 steps
#
#  Iteration 5:
# Ant 1: FAILED
# Ant 2: FAILED
# Pheromone grid:
# [[1.03 1.03 1.03]
#  [0.59 0.59 1.03]
#  [0.59 0.59 1.03]]
# Best so far: 5 steps
#
#  Iteration 6:
# Ant 1: FAILED
# Ant 2: FAILED
# Pheromone grid:
# [[0.93 0.93 0.93]
#  [0.53 0.53 0.93]
#  [0.53 0.53 0.93]]
# Best so far: 5 steps
#
#  Iteration 7:
# Ant 1: FAILED
# Ant 2: FAILED
# Pheromone grid:
# [[0.83 0.83 0.83]
#  [0.48 0.48 0.83]
#  [0.48 0.48 0.83]]
# Best so far: 5 steps
#
#  Iteration 8:
# Ant 1: FAILED
# Ant 2: FAILED
# Pheromone grid:
# [[0.75 0.75 0.75]
#  [0.43 0.43 0.75]
#  [0.43 0.43 0.75]]
# Best so far: 5 steps
#
#  Iteration 9:
# Ant 1: FAILED
# Ant 2: FAILED
# Pheromone grid:
# [[0.68 0.68 0.68]
#  [0.39 0.39 0.68]
#  [0.39 0.39 0.68]]
# Best so far: 5 steps
#
#  Iteration 10:
# Ant 1: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 2: FAILED
# Pheromone grid:
# [[0.79 0.79 0.79]
#  [0.35 0.35 0.79]
#  [0.35 0.35 0.79]]
# Best so far: 5 steps
#
#  Iteration 11:
# Ant 1: FAILED
# Ant 2: FAILED
# Pheromone grid:
# [[0.71 0.71 0.71]
#  [0.31 0.31 0.71]
#  [0.31 0.31 0.71]]
# Best so far: 5 steps
#
#  Iteration 12:
# Ant 1: FAILED
# Ant 2: FAILED
# Pheromone grid:
# [[0.64 0.64 0.64]
#  [0.28 0.28 0.64]
#  [0.28 0.28 0.64]]
# Best so far: 5 steps
#
#  Iteration 13:
# Ant 1: FAILED
# Ant 2: FAILED
# Pheromone grid:
# [[0.57 0.57 0.57]
#  [0.25 0.25 0.57]
#  [0.25 0.25 0.57]]
# Best so far: 5 steps
#
#  Iteration 14:
# Ant 1: FAILED
# Ant 2: FAILED
# Pheromone grid:
# [[0.52 0.52 0.52]
#  [0.23 0.23 0.52]
#  [0.23 0.23 0.52]]
# Best so far: 5 steps
#
#  Iteration 15:
# Ant 1: FAILED
# Ant 2: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Pheromone grid:
# [[0.65 0.65 0.65]
#  [0.21 0.21 0.65]
#  [0.21 0.21 0.65]]
# Best so far: 5 steps
#
#  Iteration 16:
# Ant 1: FAILED
# Ant 2: FAILED
# Pheromone grid:
# [[0.58 0.58 0.58]
#  [0.19 0.19 0.58]
#  [0.19 0.19 0.58]]
# Best so far: 5 steps
#
#  Iteration 17:
# Ant 1: FAILED
# Ant 2: FAILED
# Pheromone grid:
# [[0.52 0.52 0.52]
#  [0.17 0.17 0.52]
#  [0.17 0.17 0.52]]
# Best so far: 5 steps
#
#  Iteration 18:
# Ant 1: FAILED
# Ant 2: FAILED
# Pheromone grid:
# [[0.47 0.47 0.47]
#  [0.15 0.15 0.47]
#  [0.15 0.15 0.47]]
# Best so far: 5 steps
#
#  Iteration 19:
# Ant 1: FAILED
# Ant 2: FAILED
# Pheromone grid:
# [[0.42 0.42 0.42]
#  [0.14 0.14 0.42]
#  [0.14 0.14 0.42]]
# Best so far: 5 steps
#
#  Iteration 20:
# Ant 1: FAILED
# Ant 2: FAILED
# Pheromone grid:
# [[0.38 0.38 0.38]
#  [0.12 0.12 0.38]
#  [0.12 0.12 0.38]]
# Best so far: 5 steps
#
# Final Best Path: [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
#
#
#  Simulation with 20 ants:
#
#  Iteration 1:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 6: FAILED
# Ant 7: FAILED
# Ant 8: FAILED
# Ant 9: FAILED
# Ant 10: FAILED
# Ant 11: FAILED
# Ant 12: FAILED
# Ant 13: FAILED
# Ant 14: FAILED
# Ant 15: FAILED
# Ant 16: FAILED
# Ant 17: FAILED
# Ant 18: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 19: FAILED
# Ant 20: FAILED
# Pheromone grid:
# [[1.26 1.26 1.26]
#  [0.9  0.9  1.26]
#  [0.9  0.9  1.26]]
# Best so far: 5 steps
#
#  Iteration 2:
# Ant 1: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Ant 6: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 7: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 8: FAILED
# Ant 9: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 10: FAILED
# Ant 11: FAILED
# Ant 12: FAILED
# Ant 13: FAILED
# Ant 14: FAILED
# Ant 15: FAILED
# Ant 16: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 17: FAILED
# Ant 18: FAILED
# Ant 19: FAILED
# Ant 20: FAILED
# Pheromone grid:
# [[2.03 2.03 2.03]
#  [0.81 0.81 2.03]
#  [0.81 0.81 2.03]]
# Best so far: 5 steps
#
#  Iteration 3:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 4: FAILED
# Ant 5: FAILED
# Ant 6: FAILED
# Ant 7: FAILED
# Ant 8: FAILED
# Ant 9: FAILED
# Ant 10: FAILED
# Ant 11: FAILED
# Ant 12: FAILED
# Ant 13: FAILED
# Ant 14: FAILED
# Ant 15: FAILED
# Ant 16: FAILED
# Ant 17: FAILED
# Ant 18: FAILED
# Ant 19: FAILED
# Ant 20: FAILED
# Pheromone grid:
# [[2.01 2.01 2.01]
#  [0.73 0.73 2.01]
#  [0.73 0.73 2.01]]
# Best so far: 5 steps
#
#  Iteration 4:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Ant 6: FAILED
# Ant 7: FAILED
# Ant 8: FAILED
# Ant 9: FAILED
# Ant 10: FAILED
# Ant 11: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 12: FAILED
# Ant 13: FAILED
# Ant 14: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 15: FAILED
# Ant 16: FAILED
# Ant 17: FAILED
# Ant 18: FAILED
# Ant 19: FAILED
# Ant 20: FAILED
# Pheromone grid:
# [[2.17 2.17 2.17]
#  [0.66 0.66 2.17]
#  [0.66 0.66 2.17]]
# Best so far: 5 steps
#
#  Iteration 5:
# Ant 1: FAILED
# Ant 2: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 3: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 4: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 5: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 6: FAILED
# Ant 7: FAILED
# Ant 8: FAILED
# Ant 9: FAILED
# Ant 10: FAILED
# Ant 11: FAILED
# Ant 12: FAILED
# Ant 13: FAILED
# Ant 14: FAILED
# Ant 15: FAILED
# Ant 16: FAILED
# Ant 17: FAILED
# Ant 18: FAILED
# Ant 19: FAILED
# Ant 20: FAILED
# Pheromone grid:
# [[2.67 2.67 2.67]
#  [0.59 0.59 2.67]
#  [0.59 0.59 2.67]]
# Best so far: 5 steps
#
#  Iteration 6:
# Ant 1: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Ant 6: FAILED
# Ant 7: FAILED
# Ant 8: FAILED
# Ant 9: FAILED
# Ant 10: FAILED
# Ant 11: FAILED
# Ant 12: FAILED
# Ant 13: FAILED
# Ant 14: FAILED
# Ant 15: FAILED
# Ant 16: FAILED
# Ant 17: FAILED
# Ant 18: FAILED
# Ant 19: FAILED
# Ant 20: FAILED
# Pheromone grid:
# [[2.59 2.59 2.59]
#  [0.53 0.53 2.59]
#  [0.53 0.53 2.59]]
# Best so far: 5 steps
#
#  Iteration 7:
# Ant 1: FAILED
# Ant 2: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 3: FAILED
# Ant 4: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 5: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 6: FAILED
# Ant 7: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 8: FAILED
# Ant 9: FAILED
# Ant 10: FAILED
# Ant 11: FAILED
# Ant 12: FAILED
# Ant 13: FAILED
# Ant 14: FAILED
# Ant 15: FAILED
# Ant 16: FAILED
# Ant 17: FAILED
# Ant 18: FAILED
# Ant 19: FAILED
# Ant 20: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Pheromone grid:
# [[3.23 3.23 3.23]
#  [0.48 0.48 3.23]
#  [0.48 0.48 3.23]]
# Best so far: 5 steps
#
#  Iteration 8:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Ant 6: FAILED
# Ant 7: FAILED
# Ant 8: FAILED
# Ant 9: FAILED
# Ant 10: FAILED
# Ant 11: FAILED
# Ant 12: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 13: FAILED
# Ant 14: FAILED
# Ant 15: FAILED
# Ant 16: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 17: FAILED
# Ant 18: FAILED
# Ant 19: FAILED
# Ant 20: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Pheromone grid:
# [[3.44 3.44 3.44]
#  [0.43 0.43 3.44]
#  [0.43 0.43 3.44]]
# Best so far: 5 steps
#
#  Iteration 9:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Ant 6: FAILED
# Ant 7: FAILED
# Ant 8: FAILED
# Ant 9: FAILED
# Ant 10: FAILED
# Ant 11: FAILED
# Ant 12: FAILED
# Ant 13: FAILED
# Ant 14: FAILED
# Ant 15: FAILED
# Ant 16: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 17: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 18: FAILED
# Ant 19: FAILED
# Ant 20: FAILED
# Pheromone grid:
# [[3.46 3.46 3.46]
#  [0.39 0.39 3.46]
#  [0.39 0.39 3.46]]
# Best so far: 5 steps
#
#  Iteration 10:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Ant 6: FAILED
# Ant 7: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 8: FAILED
# Ant 9: FAILED
# Ant 10: FAILED
# Ant 11: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 12: FAILED
# Ant 13: FAILED
# Ant 14: FAILED
# Ant 15: FAILED
# Ant 16: FAILED
# Ant 17: FAILED
# Ant 18: FAILED
# Ant 19: FAILED
# Ant 20: FAILED
# Pheromone grid:
# [[3.47 3.47 3.47]
#  [0.35 0.35 3.47]
#  [0.35 0.35 3.47]]
# Best so far: 5 steps
#
#  Iteration 11:
# Ant 1: FAILED
# Ant 2: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Ant 6: FAILED
# Ant 7: FAILED
# Ant 8: FAILED
# Ant 9: FAILED
# Ant 10: FAILED
# Ant 11: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 12: FAILED
# Ant 13: FAILED
# Ant 14: FAILED
# Ant 15: FAILED
# Ant 16: FAILED
# Ant 17: FAILED
# Ant 18: FAILED
# Ant 19: FAILED
# Ant 20: FAILED
# Pheromone grid:
# [[3.49 3.49 3.49]
#  [0.31 0.31 3.49]
#  [0.31 0.31 3.49]]
# Best so far: 5 steps
#
#  Iteration 12:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Ant 6: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 7: FAILED
# Ant 8: FAILED
# Ant 9: FAILED
# Ant 10: FAILED
# Ant 11: FAILED
# Ant 12: FAILED
# Ant 13: FAILED
# Ant 14: FAILED
# Ant 15: FAILED
# Ant 16: FAILED
# Ant 17: FAILED
# Ant 18: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 19: FAILED
# Ant 20: FAILED
# Pheromone grid:
# [[3.5  3.5  3.5 ]
#  [0.28 0.28 3.5 ]
#  [0.28 0.28 3.5 ]]
# Best so far: 5 steps
#
#  Iteration 13:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Ant 6: FAILED
# Ant 7: FAILED
# Ant 8: FAILED
# Ant 9: FAILED
# Ant 10: FAILED
# Ant 11: FAILED
# Ant 12: FAILED
# Ant 13: FAILED
# Ant 14: FAILED
# Ant 15: FAILED
# Ant 16: FAILED
# Ant 17: FAILED
# Ant 18: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 19: FAILED
# Ant 20: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Pheromone grid:
# [[3.51 3.51 3.51]
#  [0.25 0.25 3.51]
#  [0.25 0.25 3.51]]
# Best so far: 5 steps
#
#  Iteration 14:
# Ant 1: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Ant 6: FAILED
# Ant 7: FAILED
# Ant 8: FAILED
# Ant 9: FAILED
# Ant 10: FAILED
# Ant 11: FAILED
# Ant 12: FAILED
# Ant 13: FAILED
# Ant 14: FAILED
# Ant 15: FAILED
# Ant 16: FAILED
# Ant 17: FAILED
# Ant 18: FAILED
# Ant 19: FAILED
# Ant 20: FAILED
# Pheromone grid:
# [[3.34 3.34 3.34]
#  [0.23 0.23 3.34]
#  [0.23 0.23 3.34]]
# Best so far: 5 steps
#
#  Iteration 15:
# Ant 1: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Ant 6: FAILED
# Ant 7: FAILED
# Ant 8: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 9: FAILED
# Ant 10: FAILED
# Ant 11: FAILED
# Ant 12: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 13: FAILED
# Ant 14: FAILED
# Ant 15: FAILED
# Ant 16: FAILED
# Ant 17: FAILED
# Ant 18: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 19: FAILED
# Ant 20: FAILED
# Pheromone grid:
# [[3.72 3.72 3.72]
#  [0.21 0.21 3.72]
#  [0.21 0.21 3.72]]
# Best so far: 5 steps
#
#  Iteration 16:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Ant 6: FAILED
# Ant 7: FAILED
# Ant 8: FAILED
# Ant 9: FAILED
# Ant 10: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 11: FAILED
# Ant 12: FAILED
# Ant 13: FAILED
# Ant 14: FAILED
# Ant 15: FAILED
# Ant 16: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 17: FAILED
# Ant 18: FAILED
# Ant 19: FAILED
# Ant 20: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Pheromone grid:
# [[3.89 3.89 3.89]
#  [0.19 0.19 3.89]
#  [0.19 0.19 3.89]]
# Best so far: 5 steps
#
#  Iteration 17:
# Ant 1: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Ant 6: FAILED
# Ant 7: FAILED
# Ant 8: FAILED
# Ant 9: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 10: FAILED
# Ant 11: FAILED
# Ant 12: FAILED
# Ant 13: FAILED
# Ant 14: FAILED
# Ant 15: FAILED
# Ant 16: FAILED
# Ant 17: FAILED
# Ant 18: FAILED
# Ant 19: FAILED
# Ant 20: FAILED
# Pheromone grid:
# [[3.86 3.86 3.86]
#  [0.17 0.17 3.86]
#  [0.17 0.17 3.86]]
# Best so far: 5 steps
#
#  Iteration 18:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Ant 6: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 7: FAILED
# Ant 8: FAILED
# Ant 9: FAILED
# Ant 10: FAILED
# Ant 11: FAILED
# Ant 12: FAILED
# Ant 13: FAILED
# Ant 14: FAILED
# Ant 15: FAILED
# Ant 16: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 17: FAILED
# Ant 18: FAILED
# Ant 19: FAILED
# Ant 20: FAILED
# Pheromone grid:
# [[3.84 3.84 3.84]
#  [0.15 0.15 3.84]
#  [0.15 0.15 3.84]]
# Best so far: 5 steps
#
#  Iteration 19:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Ant 6: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 7: FAILED
# Ant 8: FAILED
# Ant 9: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 10: FAILED
# Ant 11: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 12: FAILED
# Ant 13: FAILED
# Ant 14: FAILED
# Ant 15: FAILED
# Ant 16: FAILED
# Ant 17: FAILED
# Ant 18: FAILED
# Ant 19: FAILED
# Ant 20: FAILED
# Pheromone grid:
# [[3.99 3.99 3.99]
#  [0.14 0.14 3.99]
#  [0.14 0.14 3.99]]
# Best so far: 5 steps
#
#  Iteration 20:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 4: FAILED
# Ant 5: FAILED
# Ant 6: FAILED
# Ant 7: FAILED
# Ant 8: FAILED
# Ant 9: FAILED
# Ant 10: FAILED
# Ant 11: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 12: FAILED
# Ant 13: FAILED
# Ant 14: FAILED
# Ant 15: FAILED
# Ant 16: FAILED
# Ant 17: FAILED
# Ant 18: FAILED
# Ant 19: FAILED
# Ant 20: FAILED
# Pheromone grid:
# [[3.95 3.95 3.95]
#  [0.12 0.12 3.95]
#  [0.12 0.12 3.95]]
# Best so far: 5 steps
#
# Final Best Path: [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]

# %%
# Run with heuristic enabled
print("\n\n Simulation with heuristic (pheromone × 1/distance):")
run_simulation(n_ants=5, use_heuristic=True)
# Out:
#  Simulation with heuristic (pheromone × 1/distance):
#
#  Iteration 1:
# Ant 1: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 5: FAILED
# Pheromone grid:
# [[1.26 1.26 1.26]
#  [0.9  0.9  1.26]
#  [0.9  0.9  1.26]]
# Best so far: 5 steps
#
#  Iteration 2:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[1.13 1.13 1.13]
#  [0.81 0.81 1.13]
#  [0.81 0.81 1.13]]
# Best so far: 5 steps
#
#  Iteration 3:
# Ant 1: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 2: FAILED
# Ant 3: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[1.38 1.38 1.38]
#  [0.73 0.73 1.38]
#  [0.73 0.73 1.38]]
# Best so far: 5 steps
#
#  Iteration 4:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[1.24 1.24 1.24]
#  [0.66 0.66 1.24]
#  [0.66 0.66 1.24]]
# Best so far: 5 steps
#
#  Iteration 5:
# Ant 1: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 5: FAILED
# Pheromone grid:
# [[1.48 1.48 1.48]
#  [0.59 0.59 1.48]
#  [0.59 0.59 1.48]]
# Best so far: 5 steps
#
#  Iteration 6:
# Ant 1: FAILED
# Ant 2: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Pheromone grid:
# [[1.69 1.69 1.69]
#  [0.53 0.53 1.69]
#  [0.53 0.53 1.69]]
# Best so far: 5 steps
#
#  Iteration 7:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 5: FAILED
# Pheromone grid:
# [[1.7  1.7  1.7 ]
#  [0.48 0.48 1.7 ]
#  [0.48 0.48 1.7 ]]
# Best so far: 5 steps
#
#  Iteration 8:
# Ant 1: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Pheromone grid:
# [[1.89 1.89 1.89]
#  [0.43 0.43 1.89]
#  [0.43 0.43 1.89]]
# Best so far: 5 steps
#
#  Iteration 9:
# Ant 1: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 2: FAILED
# Ant 3: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[2.06 2.06 2.06]
#  [0.39 0.39 2.06]
#  [0.39 0.39 2.06]]
# Best so far: 5 steps
#
#  Iteration 10:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[2.04 2.04 2.04]
#  [0.35 0.35 2.04]
#  [0.35 0.35 2.04]]
# Best so far: 5 steps
#
#  Iteration 11:
# Ant 1: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 5: FAILED
# Pheromone grid:
# [[2.19 2.19 2.19]
#  [0.31 0.31 2.19]
#  [0.31 0.31 2.19]]
# Best so far: 5 steps
#
#  Iteration 12:
# Ant 1: FAILED
# Ant 2: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[2.15 2.15 2.15]
#  [0.28 0.28 2.15]
#  [0.28 0.28 2.15]]
# Best so far: 5 steps
#
#  Iteration 13:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[1.94 1.94 1.94]
#  [0.25 0.25 1.94]
#  [0.25 0.25 1.94]]
# Best so far: 5 steps
#
#  Iteration 14:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[1.74 1.74 1.74]
#  [0.23 0.23 1.74]
#  [0.23 0.23 1.74]]
# Best so far: 5 steps
#
#  Iteration 15:
# Ant 1: FAILED
# Ant 2: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[1.75 1.75 1.75]
#  [0.21 0.21 1.75]
#  [0.21 0.21 1.75]]
# Best so far: 5 steps
#
#  Iteration 16:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[1.57 1.57 1.57]
#  [0.19 0.19 1.57]
#  [0.19 0.19 1.57]]
# Best so far: 5 steps
#
#  Iteration 17:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[1.6  1.6  1.6 ]
#  [0.17 0.17 1.6 ]
#  [0.17 0.17 1.6 ]]
# Best so far: 5 steps
#
#  Iteration 18:
# Ant 1: FAILED
# Ant 2: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[1.62 1.62 1.62]
#  [0.15 0.15 1.62]
#  [0.15 0.15 1.62]]
# Best so far: 5 steps
#
#  Iteration 19:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 4: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 5: FAILED
# Pheromone grid:
# [[1.82 1.82 1.82]
#  [0.14 0.14 1.82]
#  [0.14 0.14 1.82]]
# Best so far: 5 steps
#
#  Iteration 20:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[1.81 1.81 1.81]
#  [0.12 0.12 1.81]
#  [0.12 0.12 1.81]]
# Best so far: 5 steps
#
# Final Best Path: [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]

# %%
# Run with independent ants (delayed pheromone updates)
print("\n\n Simulation with independent ants (knowledge sharing after iteration):")
run_simulation(n_ants=5, use_heuristic=False, independent=True)
# Out:
#  Simulation with independent ants (knowledge sharing after iteration):
#
#  Iteration 1:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[0.9 0.9 0.9]
#  [0.9 0.9 0.9]
#  [0.9 0.9 0.9]]
# Best so far: None steps
#
#  Iteration 2:
# Ant 1: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[0.99 0.99 0.99]
#  [0.81 0.81 0.99]
#  [0.81 0.81 0.99]]
# Best so far: 5 steps
#
#  Iteration 3:
# Ant 1: FAILED
# Ant 2: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 3: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[1.25 1.25 1.25]
#  [0.73 0.73 1.25]
#  [0.73 0.73 1.25]]
# Best so far: 5 steps
#
#  Iteration 4:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[1.13 1.13 1.13]
#  [0.66 0.66 1.13]
#  [0.66 0.66 1.13]]
# Best so far: 5 steps
#
#  Iteration 5:
# Ant 1: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[1.19 1.19 1.19]
#  [0.59 0.59 1.19]
#  [0.59 0.59 1.19]]
# Best so far: 5 steps
#
#  Iteration 6:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[1.07 1.07 1.07]
#  [0.53 0.53 1.07]
#  [0.53 0.53 1.07]]
# Best so far: 5 steps
#
#  Iteration 7:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[0.97 0.97 0.97]
#  [0.48 0.48 0.97]
#  [0.48 0.48 0.97]]
# Best so far: 5 steps
#
#  Iteration 8:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[0.87 0.87 0.87]
#  [0.43 0.43 0.87]
#  [0.43 0.43 0.87]]
# Best so far: 5 steps
#
#  Iteration 9:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Pheromone grid:
# [[0.96 0.96 0.96]
#  [0.39 0.39 0.96]
#  [0.39 0.39 0.96]]
# Best so far: 5 steps
#
#  Iteration 10:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[0.87 0.87 0.87]
#  [0.35 0.35 0.87]
#  [0.35 0.35 0.87]]
# Best so far: 5 steps
#
#  Iteration 11:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 5: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Pheromone grid:
# [[1.14 1.14 1.14]
#  [0.31 0.31 1.14]
#  [0.31 0.31 1.14]]
# Best so far: 5 steps
#
#  Iteration 12:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[1.03 1.03 1.03]
#  [0.28 0.28 1.03]
#  [0.28 0.28 1.03]]
# Best so far: 5 steps
#
#  Iteration 13:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 5: FAILED
# Pheromone grid:
# [[1.1  1.1  1.1 ]
#  [0.25 0.25 1.1 ]
#  [0.25 0.25 1.1 ]]
# Best so far: 5 steps
#
#  Iteration 14:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[0.99 0.99 0.99]
#  [0.23 0.23 0.99]
#  [0.23 0.23 0.99]]
# Best so far: 5 steps
#
#  Iteration 15:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 5: FAILED
# Pheromone grid:
# [[1.07 1.07 1.07]
#  [0.21 0.21 1.07]
#  [0.21 0.21 1.07]]
# Best so far: 5 steps
#
#  Iteration 16:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[0.97 0.97 0.97]
#  [0.19 0.19 0.97]
#  [0.19 0.19 0.97]]
# Best so far: 5 steps
#
#  Iteration 17:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 4: FAILED
# Ant 5: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Pheromone grid:
# [[1.23 1.23 1.23]
#  [0.17 0.17 1.23]
#  [0.17 0.17 1.23]]
# Best so far: 5 steps
#
#  Iteration 18:
# Ant 1: FAILED
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Pheromone grid:
# [[1.29 1.29 1.29]
#  [0.15 0.15 1.29]
#  [0.15 0.15 1.29]]
# Best so far: 5 steps
#
#  Iteration 19:
# Ant 1: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 2: FAILED
# Ant 3: FAILED
# Ant 4: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 5: FAILED
# Pheromone grid:
# [[1.52 1.52 1.52]
#  [0.14 0.14 1.52]
#  [0.14 0.14 1.52]]
# Best so far: 5 steps
#
#  Iteration 20:
# Ant 1: FAILED
# Ant 2: SUCCESS (len 5) [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Ant 3: FAILED
# Ant 4: FAILED
# Ant 5: FAILED
# Pheromone grid:
# [[1.55 1.55 1.55]
#  [0.12 0.12 1.55]
#  [0.12 0.12 1.55]]
# Best so far: 5 steps
#
# Final Best Path: [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
